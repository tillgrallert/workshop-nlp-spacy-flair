# %% [markdown]
# # spaCy Basics

# %% [markdown]
# ## Ressourcen
#
# https://spacy.io/
#
# ### Docs und Tutorials
#
# https://spacy.io/usage
#
# ### Sprachmodelle
#
# https://spacy.io/models
#
# https://spacy.io/models/de
#
# ### API
#
# https://spacy.io/api
#
# ### Kurs
#
# https://course.spacy.io/de
#
# ### Video Tutorials
#
# https://www.youtube.com/c/ExplosionAI
#
# ### Jupyter Book NER mit SpaCy
#
# http://ner.pythonhumanities.com/intro.html
#
# ### Sammlung von Ressourcen zu SpaCy
#
# https://spacy.io/universe

# %% [markdown]
# ## Installation mit pip und conda

# %%
# !pip install spacy==3.2.1
# conda install spacy==3.2.1

# %% [markdown]
# ## Herunterladen des deutschen Sprachmodells (Language Model, LM)
#
# Es gibt drei verschiedene Größen:
# * small: de_core_news_sm, 18MB
# * medium: de_core_news_md, 46MB
# * large: de_core_news_lg, 545MB
# * **neu** transformer-based: de_dep_news_trf, 348MB

# %%
 # !python -m spacy download de_core_news_md

# %% [markdown]
# ## Import

# %%
import spacy

# %%
# check version
print(spacy.__version__)
# Out:
# 3.2.1

# %% [markdown]
# ## Laden des Sprachmodells

# %%
nlp = spacy.load('de_core_news_md') 

# zum Ausschalten einzelner Komponenten
# nlp = spacy.load('de_core_news_md', disable=['parser', 'tagger'])

# %% [markdown]
# ## geladene Komponenten checken
#
# Der Befehl listet alle Komponenten der Pipline auf. Spacy hat zwei Komopnenten
#
# 1. Pipeline onjects: können einzeln (nach)trainiert und ausgeschaltet werden
#     - lemmatizer
#     - tagger: part of speech
#     - tok2vec:
# 2. Container objects: Tokens, Spans und Document werden mit Attributen versehen

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x11e32a640>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x11e4e2a00>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x11e4e2a60>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x11e3b02e0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x11e4ea140>),
#  ('lemmatizer', <spacy.pipeline.lemmatizer.Lemmatizer at 0x11e4ea0c0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x11e3b06d0>)]

# %% [markdown]
# ## Textdaten einlesen

# %% [markdown]
# entnommen von:
#
# https://www.tagesschau.de/ausland/amerika/russland-ukraine-157.html

# %%
text = '''Biden befürchtet Einmarsch "in den nächsten Tagen"
            Stand: 18.02.2022 06:01 Uhr
            Die Gefahr eines russischen Einmarsches in die Ukraine schätzt US-Präsident Biden als "sehr hoch" ein - schon in den kommenden Tagen könne es dazu kommen. Die russische Regierung wies den Vize-US-Botschafter in Moskau aus.
            US-Präsident Joe Biden befürchtet trotz aller Beteuerungen aus Moskau einen russischen Einmarsch in die Ukraine in den kommenden Tagen. Biden sagte, die Gefahr einer Invasion sei "sehr hoch". Nach seiner Einschätzung könne es "in den nächsten paar Tagen" dazu kommen. Es gebe keine Pläne dafür, dass er mit dem russischen Präsidenten Wladimir Putin telefonieren werde, fügte er hinzu.
            Der Kreml erklärte laut der russischen Agentur RIA, Bidens Warnung verstärke die Spannungen noch. Der stellvertretende Außenminister Sergej Werschinin wies vor dem UN-Sicherheitsrat die Befürchtungen des Westens vor einem bevorstehenden Einmarsch erneut zurück. "Ich denke, wir haben genug darüber spekuliert", sagte er. Eine Invasion sei entgegen der Warnungen ausgeblieben. In Richtung der USA und ihrer westlichen Verbündeten sagte Werschinin: "Mein Rat an Sie ist, sich nicht in eine unangenehme Situation zu begeben."
            Biden will am heutigen Freitag mit Verbündeten über das weitere Vorgehen beraten. Themen der Telefonschalte am Nachmittag (Ortszeit) sollten unter anderem die Aufstockung der russischen Truppen an der Grenze zur Ukraine und weitere diplomatische Bemühungen sein, hieß es aus dem Weißen Haus. Neben Kanadas Premierminister Justin Trudeau sollen führende Politiker aus Deutschland, Frankreich, Großbritannien, Italien, Polen und Rumänien an dem Gespräch teilnehmen, teilte Trudeaus Büro am Donnerstagabend (Ortszeit) mit. Auch die Europäische Union und die NATO seien vertreten.
            US-Außenminister Antony Blinken will sich nächste Woche mit seinem russischen Kollegen Sergej Lawrow treffen - solange Russland nicht in der Ukraine einmarschiert. Blinken habe vorgeschlagen, sich mit Lawrow "nächste Woche in Europa zu treffen. Die Russen haben mit Terminvorschlägen für Ende nächster Woche geantwortet, was wir unter der Bedingung akzeptiert haben, dass es keine russische Invasion der Ukraine gibt", erklärte der Sprecher des Außenministeriums, Ned Price, am Abend.
            Zuvor hatte Blinken vor dem UN-Sicherheitsrat ebenfalls gewarnt, Russland bereite sich auf einen Angriff in den kommenden Tagen vor. Russlands Plan sei, dafür einen Vorwand zu schaffen. "Dies könnte ein gewaltsames Ereignis sein, das Russland gegen die Ukraine vorbringen wird, oder eine unerhörte Anschuldigung, die Russland gegen die ukrainische Regierung erheben wird", sagte er. Möglich wären ihm zufolge ein vermeintlicher Terroranschlag in Russland, die "erfundene Entdeckung eines Massengrabes" und Vorwürfe eines Völkermordes, ein inszenierter Drohnenangriff auf Zivilisten oder ein vorgetäuschter oder echter Angriff mit Chemiewaffen.
            Russische Medien würden bereits "falsche Alarme" verbreiten, so Blinken. Ein russischer Angriff könne auch die ukrainische Hauptstadt Kiew einbeziehen. Der US-Außenminister betonte, Diplomatie sei weiter der wichtigste Weg zur Lösung der Krise. Er habe daher seinem russischen Amtskollegen Sergej Lawrow ein persönliches Treffen in der kommenden Woche vorgeschlagen. 
            '''

# %% [markdown]
# ## Doc-Objekt erstellen
#
# Benennungen von `nlp()` und `doc` sind Konvention

# %%
# This is were the magic happens!
doc = nlp(text)

# %% [markdown]
# ## Im Token-Objekt hinterlegte Informationen
#
# https://spacy.io/api/token#attributes

# %%
# iteriere über die ersten 20 Tokens
for token in doc[:20]:
    print(f'''Token: {token}  
              Lemmata: {token.lemma_} 
              POS: {token.pos_}
              explain POS: {spacy.explain(token.pos_)}
              TAG: {token.tag_}
              explain TAG: {spacy.explain(token.tag_)}
              Dependency: {token.dep_}
              explain Dependency: {spacy.explain(token.dep_)}
              Entity: {token.ent_type_}''')
# Out:
# Token: Biden
#               Lemmata: Biden
#               POS: PROPN
#               explain POS: proper noun
#               TAG: NE
#               explain TAG: proper noun
#               Dependency: sb
#               explain Dependency: subject
#               Entity: PER
# Token: befürchtet
#               Lemmata: befürchten
#               POS: VERB
#               explain POS: verb
#               TAG: VVFIN
#               explain TAG: finite verb, full
#               Dependency: ROOT
#               explain Dependency: None
#               Entity:
# Token: Einmarsch
#               Lemmata: Einmarsch
#               POS: NOUN
#               explain POS: noun
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: oa
#               explain Dependency: accusative object
#               Entity:
# Token: "
#               Lemmata: "
#               POS: PUNCT
#               explain POS: punctuation
#               TAG: $(
#               explain TAG: other sentence-internal punctuation mark
#               Dependency: punct
#               explain Dependency: punctuation
#               Entity:
# Token: in
#               Lemmata: in
#               POS: ADP
#               explain POS: adposition
#               TAG: APPR
#               explain TAG: preposition; circumposition left
#               Dependency: mo
#               explain Dependency: modifier
#               Entity:
# Token: den
#               Lemmata: der
#               POS: DET
#               explain POS: determiner
#               TAG: ART
#               explain TAG: definite or indefinite article
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: nächsten
#               Lemmata: nächst
#               POS: ADJ
#               explain POS: adjective
#               TAG: ADJA
#               explain TAG: adjective, attributive
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: Tagen
#               Lemmata: Tag
#               POS: NOUN
#               explain POS: noun
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: "
#               Lemmata: "
#               POS: PUNCT
#               explain POS: punctuation
#               TAG: $(
#               explain TAG: other sentence-internal punctuation mark
#               Dependency: punct
#               explain Dependency: punctuation
#               Entity:
# Token:
#
#               Lemmata:
#
#               POS: SPACE
#               explain POS: space
#               TAG: _SP
#               explain TAG: whitespace
#               Dependency: dep
#               explain Dependency: unclassified dependent
#               Entity:
# Token: Stand
#               Lemmata: Stand
#               POS: NOUN
#               explain POS: noun
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: ROOT
#               explain Dependency: None
#               Entity:
# Token: :
#               Lemmata: :
#               POS: PUNCT
#               explain POS: punctuation
#               TAG: $.
#               explain TAG: sentence-final punctuation mark
#               Dependency: punct
#               explain Dependency: punctuation
#               Entity:
# Token: 18.02.2022
#               Lemmata: 18.02.2022
#               POS: X
#               explain POS: other
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: 06:01
#               Lemmata: 06:01
#               POS: NUM
#               explain POS: numeral
#               TAG: CARD
#               explain TAG: cardinal number
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: Uhr
#               Lemmata: Uhr
#               POS: NOUN
#               explain POS: noun
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: mnr
#               explain Dependency: postnominal modifier
#               Entity:
# Token:
#
#               Lemmata:
#
#               POS: SPACE
#               explain POS: space
#               TAG: _SP
#               explain TAG: whitespace
#               Dependency: dep
#               explain Dependency: unclassified dependent
#               Entity:
# Token: Die
#               Lemmata: der
#               POS: DET
#               explain POS: determiner
#               TAG: ART
#               explain TAG: definite or indefinite article
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: Gefahr
#               Lemmata: Gefahr
#               POS: NOUN
#               explain POS: noun
#               TAG: NN
#               explain TAG: noun, singular or mass
#               Dependency: oa
#               explain Dependency: accusative object
#               Entity:
# Token: eines
#               Lemmata: ein
#               POS: DET
#               explain POS: determiner
#               TAG: ART
#               explain TAG: definite or indefinite article
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity:
# Token: russischen
#               Lemmata: russisch
#               POS: ADJ
#               explain POS: adjective
#               TAG: ADJA
#               explain TAG: adjective, attributive
#               Dependency: nk
#               explain Dependency: noun kernel element
#               Entity: MISC

# %% [markdown]
# ## Im Doc-Objekt hinterlegte Informationen
#
# https://spacy.io/api/doc

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc.lang_
# Out:
# 'de'

# %% [markdown]
# ### Entities

# %%
# Entities

print(type(doc.ents)) # data type
print(len(doc.ents)) # length of data frame, i.e. number of entites
print(doc.ents) # return the entities
# Out:
# <class 'tuple'>
# 61
# (Biden, russischen, Ukraine, US-Präsident, Biden, russische Regierung, Vize-US-Botschafter, Moskau, US-Präsident, Joe Biden, Moskau, russischen, Ukraine, Biden, russischen, Wladimir Putin, russischen, RIA, Sergej Werschinin, UN-Sicherheitsrat, Invasion, USA, Telefonschalte, russischen, Grenze, Ukraine, Weißen Haus, Kanadas, Justin Trudeau, Deutschland, Frankreich, Großbritannien, Italien, Polen, Rumänien, Trudeaus, Europäische Union, NATO, Antony Blinken, russischen, Sergej Lawrow, Russland, Ukraine, Lawrow, Europa, Russen, russische, Außenministeriums, Ned Price,, Abend., Blinken, UN-Sicherheitsrat, Russland, Russlands Plan, Russland, Ukraine, Russland, ukrainische Regierung, Russland, Blinken., russischer, ukrainische, Kiew, US-Außenminister, russischen, Sergej Lawrow)

# %%
# prüfen des Token-Objekts

for token in doc:

    if token.ent_type_ == 'PER':
        print(token, token.ent_type_)
# Out:
# Biden PER
# Biden PER
# Joe PER
# Biden PER
# Biden PER
# Wladimir PER
# Putin PER
# Sergej PER
# Werschinin PER
# Telefonschalte PER
# Justin PER
# Trudeau PER
# Trudeaus PER
# Antony PER
# Blinken PER
# Sergej PER
# Lawrow PER
# Lawrow PER
# Blinken PER
# Sergej PER
# Lawrow PER

# %%
# Prüfen des Label der Entities im Doc-Objekt

for ent in doc.ents:
# ORG, LOC, PER
    if ent.label_ == 'LOC': 
        print(ent.text, ent.label_)
# Out:
# Ukraine LOC
# US-Präsident LOC
# russische Regierung LOC
# Moskau LOC
# US-Präsident LOC
# Moskau LOC
# Ukraine LOC
# USA LOC
# Ukraine LOC
# Weißen Haus LOC
# Kanadas LOC
# Deutschland, Frankreich, Großbritannien, Italien, Polen LOC
# Rumänien LOC
# Russland LOC
# Ukraine LOC
# Europa LOC
# Russland LOC
# Russland LOC
# Ukraine LOC
# Russland LOC
# Russland LOC
# Kiew LOC

# %% [markdown]
# setting a list object creates a list of unique values. the sequence can change between runs

# %%
personen_liste = { str(token) for token in doc  if token.ent_type_ == 'PER' }
print(personen_liste)
# Out:
# {'Antony', 'Joe', 'Wladimir', 'Blinken', 'Lawrow', 'Trudeaus', 'Trudeau', 'Telefonschalte', 'Sergej', 'Biden', 'Justin', 'Putin', 'Werschinin'}

# %%
for entity in ['PER', 'ORG', 'LOC', 'MISC']:
    print(entity)
    # print({ str(token) for token in doc  if token.ent_type_ == entity })
    print({ str(token.lemma_) for token in doc  if token.ent_type_ == entity }) # for outputting list of unique lemmas
    print('\n')
# Out:
# PER
# {'Antony', 'Joe', 'Wladimir', 'Blinken', 'Lawrow', 'Trudeaus', 'Trudeau', 'Telefonschalte', 'Sergej', 'Biden', 'Justin', 'Putin', 'Werschinin'}
#
#
# ORG
# {'RIA', 'Union', 'US-Außenminister', 'europäisch', 'NATO', 'ukrainische', 'Regierung', 'UN-Sicherheitsrat', 'Vize-US-Botschafter'}
#
#
# LOC
# {'USA', 'Regierung', 'Russland', 'Frankreich', 'Deutschland', 'russische', 'US-Präsident', 'Kanada', 'Weiße', ',', 'Haus', 'Ukraine', 'Italien', 'Kiew', 'Rumänien', 'Moskau', 'Großbritannien', 'Pol', 'Europa'}
#
#
# MISC
# {'Blinken', 'russische', 'Invasion', 'Russe', 'Grenze', '.', 'Price', 'ukrainische', 'Plan', 'Russlands', 'Außenministerium', 'Abend', 'Ned', 'russisch', ','}

# %% [markdown]
# ## Visualisieren der Entities

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  befürchtet Einmarsch &quot;in den nächsten Tagen&quot;</br>            Stand: 18.02.2022 06:01 Uhr</br>            Die Gefahr eines
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russischen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Einmarsches in die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  schätzt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US-Präsident
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  als &quot;sehr hoch&quot; ein - schon in den kommenden Tagen könne es dazu kommen. Die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russische Regierung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  wies den
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vize-US-Botschafter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Moskau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  aus.</br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US-Präsident
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  befürchtet trotz aller Beteuerungen aus
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Moskau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  einen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russischen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Einmarsch in die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in den kommenden Tagen.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sagte, die Gefahr einer Invasion sei &quot;sehr hoch&quot;. Nach seiner Einschätzung könne es &quot;in den nächsten paar Tagen&quot; dazu kommen. Es gebe keine Pläne dafür, dass er mit dem
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russischen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Präsidenten
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  telefonieren werde, fügte er hinzu.</br>            Der Kreml erklärte laut der
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russischen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Agentur
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Bidens Warnung verstärke die Spannungen noch. Der stellvertretende Außenminister
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sergej Werschinin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  wies vor dem
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UN-Sicherheitsrat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  die Befürchtungen des Westens vor einem bevorstehenden Einmarsch erneut zurück. &quot;Ich denke, wir haben genug darüber spekuliert&quot;, sagte er. Eine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Invasion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  sei entgegen der Warnungen ausgeblieben. In Richtung der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  und ihrer westlichen Verbündeten sagte Werschinin: &quot;Mein Rat an Sie ist, sich nicht in eine unangenehme Situation zu begeben.&quot;</br>            Biden will am heutigen Freitag mit Verbündeten über das weitere Vorgehen beraten. Themen der
# <mark class="entity" sty

# %%
# dependency parser
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="d54a8c0caee444009436899d66f68c33-0" class="displacy" width="80725" height="1887.0" direction="ltr" style="max-width: none; height: 1887.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Biden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">befürchtet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Einmarsch &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">nächsten</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Tagen&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">
#             </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Stand:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">18.02.2022</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">06:01</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Uhr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">
#             </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Die</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Gefahr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">eines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">russischen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Einmarsches</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">die</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Ukraine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">schätzt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">US-Präsident</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Biden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">als &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">sehr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">hoch&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">ein -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">schon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill=

# %%
# html does not work

# from pathlib import Path
# html = displacy.render(doc, style='ent', page=True)
# output_path = Path('../img/ents_v2.html')
# output_path.open('w', encoding='utf8').write(html)

# %% [markdown]
# # Sentences

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Biden befürchtet Einmarsch "in den nächsten Tagen"
#
#             Stand: 18.02.2022 06:01 Uhr
#
# Die Gefahr eines russischen Einmarsches in die Ukraine schätzt US-Präsident Biden als "sehr hoch" ein - schon in den kommenden Tagen könne es dazu kommen.
# Die russische Regierung wies den Vize-US-Botschafter in Moskau aus.
#
#             US-Präsident Joe Biden befürchtet trotz aller Beteuerungen aus Moskau einen russischen Einmarsch in die Ukraine in den kommenden Tagen.
# Biden sagte, die Gefahr einer Invasion sei "sehr hoch".
# Nach seiner Einschätzung könne es "in den nächsten paar Tagen" dazu kommen.
# Es gebe keine Pläne dafür, dass er mit dem russischen Präsidenten Wladimir Putin telefonieren werde, fügte er hinzu.
#
#             Der Kreml erklärte laut der russischen Agentur RIA, Bidens Warnung verstärke die Spannungen noch.
# Der stellvertretende Außenminister Sergej Werschinin wies vor dem UN-Sicherheitsrat die Befürchtungen des Westens vor einem bevorstehenden Einmarsch erneut zurück.
# "Ich denke, wir haben genug darüber spekuliert", sagte er.
# Eine Invasion sei entgegen der Warnungen ausgeblieben.
# In Richtung der USA und ihrer westlichen Verbündeten sagte Werschinin: "Mein Rat an Sie ist, sich nicht in eine unangenehme Situation zu begeben.
# "
#             Biden will am heutigen Freitag mit Verbündeten über das weitere Vorgehen beraten.
# Themen der Telefonschalte am Nachmittag (Ortszeit) sollten unter anderem die Aufstockung der russischen Truppen an der Grenze zur Ukraine und weitere diplomatische Bemühungen sein, hieß es aus dem Weißen Haus.
# Neben Kanadas Premierminister Justin Trudeau sollen führende Politiker aus Deutschland, Frankreich, Großbritannien, Italien, Polen und Rumänien an dem Gespräch teilnehmen, teilte Trudeaus Büro am Donnerstagabend (Ortszeit) mit.
# Auch die Europäische Union und die NATO seien vertreten.
#
#             US-Außenminister Antony Blinken will sich nächste Woche mit seinem russischen Kollegen Sergej Lawrow treffen - solange Russland nicht in der Ukraine einmarschiert.
# Blinken habe vorgeschlagen, sich mit Lawrow "nächste Woche in Europa zu treffen.
# Die Russen haben mit Terminvorschlägen für Ende nächster Woche geantwortet, was wir unter der Bedingung akzeptiert haben, dass es keine russische Invasion der Ukraine gibt", erklärte der Sprecher des Außenministeriums, Ned Price, am Abend.
#
#             Zuvor hatte Blinken vor dem UN-Sicherheitsrat ebenfalls gewarnt, Russland bereite sich auf einen Angriff in den kommenden Tagen vor.
# Russlands Plan sei, dafür einen Vorwand zu schaffen.
# "Dies könnte ein gewaltsames Ereignis sein, das Russland gegen die Ukraine vorbringen wird, oder eine unerhörte Anschuldigung, die Russland gegen die ukrainische Regierung erheben wird", sagte er.
# Möglich wären ihm zufolge ein vermeintlicher Terroranschlag in Russland, die "erfundene Entdeckung eines Massengrabes" und Vorwürfe eines Völkermordes, ein inszenierter Drohnenangriff auf Zivilisten oder ein vorgetäuschter oder echter Angriff mit Chemiewaffen.
#
#             Russische Medien würden bereits "falsche Alarme" verbreiten, so Blinken.
# Ein russischer Angriff könne auch die ukrainische Hauptstadt Kiew einbeziehen.
# Der US-Außenminister betonte, Diplomatie sei weiter der wichtigste Weg zur Lösung der Krise.
# Er habe daher seinem russischen Amtskollegen Sergej Lawrow ein persönliches Treffen in der kommenden Woche vorgeschlagen.

# %%
# Noun chunks

# %%
chunk_liste = [] # the list is not strictly necessary

for chunk in doc.noun_chunks:
    # find chunks which contain persons
    for token in chunk:
        if token.ent_type_ == 'PER':
            print (chunk)
            chunk_liste.append(chunk)
print(chunk_liste)
print(set(chunk_liste))
# Out:
# Biden
# US-Präsident Biden
# US-Präsident Joe Biden
# US-Präsident Joe Biden
# Biden
# dem russischen Präsidenten Wladimir Putin
# dem russischen Präsidenten Wladimir Putin
# Der stellvertretende Außenminister Sergej Werschinin
# Der stellvertretende Außenminister Sergej Werschinin
# der Telefonschalte
# Justin Trudeau
# Justin Trudeau
# Trudeaus
# US-Außenminister Antony Blinken
# US-Außenminister Antony Blinken
# seinem russischen Kollegen Sergej Lawrow
# seinem russischen Kollegen Sergej Lawrow
# Lawrow
# Blinken
# seinem russischen Amtskollegen Sergej Lawrow
# seinem russischen Amtskollegen Sergej Lawrow
# [Biden, US-Präsident Biden, US-Präsident Joe Biden, US-Präsident Joe Biden, Biden, dem russischen Präsidenten Wladimir Putin, dem russischen Präsidenten Wladimir Putin, Der stellvertretende Außenminister Sergej Werschinin, Der stellvertretende Außenminister Sergej Werschinin, der Telefonschalte, Justin Trudeau, Justin Trudeau, Trudeaus, US-Außenminister Antony Blinken, US-Außenminister Antony Blinken, seinem russischen Kollegen Sergej Lawrow, seinem russischen Kollegen Sergej Lawrow, Lawrow, Blinken, seinem russischen Amtskollegen Sergej Lawrow, seinem russischen Amtskollegen Sergej Lawrow]
# {seinem russischen Kollegen Sergej Lawrow, Trudeaus, Justin Trudeau, Biden, US-Präsident Joe Biden, Lawrow, US-Außenminister Antony Blinken, Blinken, seinem russischen Amtskollegen Sergej Lawrow, Biden, dem russischen Präsidenten Wladimir Putin, US-Präsident Biden, Der stellvertretende Außenminister Sergej Werschinin, der Telefonschalte}
